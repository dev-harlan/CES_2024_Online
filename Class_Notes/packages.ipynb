# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ----------------
# affine                   2.4.0
# alabaster                0.7.12
# anyio                    3.5.0
# appdirs                  1.4.4
# apturl                   0.5.2
# argon2-cffi              21.1.0
# asciitree                0.3.3
# attrs                    21.2.0
# Babel                    2.8.0
# backcall                 0.2.0
# bcrypt                   3.2.0
# beautifulsoup4           4.10.0
# beniget                  0.4.1
# bleach                   4.1.0
# blinker                  1.4
# blosc                    1.9.2
# Bottleneck               1.3.2
# Brlapi                   0.8.3
# Brotli                   1.0.9
# Cartopy                  0.0.0
# cdo                      1.5.6
# certifi                  2020.6.20
# cftime                   1.5.2
# chardet                  4.0.0
# click                    8.0.3
# click-plugins            1.1.1
# cligj                    0.7.2
# ...
