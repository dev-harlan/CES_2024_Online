# %%
# A hello:
print("Hello Chopin")

#Logistic Map
A = 0.7
x0 = 0.5

print("Ax(1-x), A = ", A, "x = ",x0, "\n" )

for i in range(50):
    xn = A*x0*(1-x0)
    print(i, ": ", xn)
    x0 = xn
# Out:
# Hello Chopin
# Ax(1-x), A =  0.7 x =  0.5
#
# 0 :  0.175
# 1 :  0.10106249999999999
# 2 :  0.06359420976562499
# 3 :  0.041684990374937475
# 4 :  0.027963146366665192
# 5 :  0.019026846168359157
# 6 :  0.013065377705271327
# 7 :  0.009026271527482949
# 8 :  0.006261358564856569
# 9 :  0.004355507767645206
# 10 :  0.0030355761238118318
# 11 :  0.0021184529809858627
# 12 :  0.00147977559656725
# 13 :  0.0010343101025257378
# 14 :  0.0007232682135962856
# 15 :  0.0005059215676812408
# 16 :  0.00035396592773401697
# 17 :  0.0002476884450992142
# 18 :  0.00017333896687336494
# 19 :  0.00012131624433314974
# 20 :  8.491106869140745e-05
# 21 :  5.943270116127478e-05
# 22 :  4.1600418240715215e-05
# 23 :  2.9119081352142186e-05
# 24 :  2.0382763401870373e-05
# 25 :  1.4267643561378533e-05
# 26 :  9.987207997008017e-06
# 27 :  6.990975776879108e-06
# 28 :  4.893648832195757e-06
# 29 :  3.425537419077805e-06
# 30 :  2.3978679793398368e-06
# 31 :  1.6785035606982932e-06
# ...

# %%
x1 = A*x0*(1-x0)
print("x1 ", x1)

x2= A*x1*(1-x1)
print("x2 ", x2)

x3 = A*x2*(1-x2)
print("x3 ", x3)
# Out:
# x1  0.175
# x2  0.10106249999999999
# x3  0.06359420976562499
